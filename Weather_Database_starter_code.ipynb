# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
# from config import weather_api_key
weather_api_key=""

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# # Create an empty list to hold weather data for each city
# city_data = []

# # Print a message to indicate that the data retrieval starts
# print("Beginning Data Retrieval     ")
# print("-----------------------------")

# # Create counters and set them to 1
# record_count = 1
# set_count = 1

# # Loop through all the cities in our list to fetch weather data for each city
# for i, city in enumerate(cities):
        
#     # Group cities in sets of 50 for logging purposes
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#         time.sleep(60)

#     # Create an endpoint URL for each city
#     city_url = url + "&q=" + city.replace(" ","+")
    
#     # Log the url, record, and set numbers
#     print(f"Processing Record {record_count} of Set {set_count} | {city}")

#     # Add 1 to the record count
#     record_count += 1

#     # Run an API request for each of the cities
#     try:
#         city_weather = requests.get(city_url).json()
#         # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
#         # YOUR CODE HERE       
            
#         # Append the city information into the city_data list
#         # YOUR CODE HERE
    
#     # If an error is experienced, skip the city
#     except:
#         print("City not found. Skipping...")
#         pass

# # Indicate that the data retrieval is complete 
# print("-----------------------------")
# print("Data Retrieval Complete      ")
# print("-----------------------------")

# %%
# # Create an empty list to hold the weather data.
# city_data = []
# # Print the beginning of the logging.
# print("Beginning Data Retrieval     ")
# print("-----------------------------")

# # Create counters.
# record_count = 1
# set_count = 1

# # Loop through all the cities in our list.
# for i in range(len(cities)):

#     # Group cities in sets of 50 for logging purposes.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#         time.sleep(60)

#     # Create endpoint URL with each city.
#     city_url = url + "&q=" + cities[i]
    
    
#     # Loop through all the cities in the list.
# for i, city in enumerate(cities):

#     # Group cities in sets of 50 for logging purposes.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#         time.sleep(60)

#     # Create endpoint URL with each city.
#     city_url = url + "&q=" + city.replace(" ","+")

#     # Log the URL, record, and set numbers and the city.
#     print(f"Processing Record {record_count} of Set {set_count} | {city}")
#     # Add 1 to the record count.
#     record_count += 1

# # # try:
# # #   Do something
# # # except:
# # #   print("An exception occurred")

# # # Run an API request for each of the cities.
#     try:
#         # Parse the JSON and retrieve data.
#         city_weather = requests.get(city_url).json()
#         # Parse out the needed data.
#         city_lat = city_weather["coord"]["lat"]
#         city_lng = city_weather["coord"]["lon"]
#         city_max_temp = city_weather["main"]["temp_max"]
#         city_humidity = city_weather["main"]["humidity"]
#         city_clouds = city_weather["clouds"]["all"]
#         city_wind = city_weather["wind"]["speed"]
#         city_country = city_weather["sys"]["country"]
#         # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
#         # Append the city information into city_data list.
#         city_data.append({"City": city.title(),
#                           "Lat": city_lat,
#                           "Lng": city_lng,
#                           "Max Temp": city_max_temp,
#                           "Humidity": city_humidity,
#                           "Cloudiness": city_clouds,
#                           "Wind Speed": city_wind,
#                           "Country": city_country,
#                           "Date": city_date})

# # If an error is experienced, skip the city.
#     except:
#         print("City not found. Skipping...")
#         pass

# # Indicate that Data Loading is complete.
# # print("-----------------------------")
# print("Data Retrieval Complete      ")
# print("-------------------")

# %%
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    
# # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        desc = city_weather["weather"][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":desc
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | abbeville
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | xuddur
# Processing Record 5 of Set 1 | mbandaka
# Processing Record 6 of Set 1 | tessalit
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | gravdal
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 1 | bathsheba
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 1 | matagami
# Processing Record 19 of Set 1 | saint george
# Processing Record 20 of Set 1 | barra patuca
# Processing Record 21 of Set 1 | mazarron
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | buala
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 1 | abha
# Processing Record 27 of Set 1 | korla
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | honningsvag
# Processing Record 30 of Set 1 | chuy
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | lagos
# Processing Record 34 of Set 1 | santa cruz del sur
# Processing Record 35 of Set 1 | sao filipe
# Processing Record 36 of Set 1 | ingham
# Processing Record 37 of Set 1 | safonovo
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | berlevag
# Processing Record 42 of Set 1 | kulu
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 1 | cherskiy
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | arucas
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | palmares do sul
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 0 of Set 2 | dikson
# Processing Record 1 of Set 2 | port alfred
# Processing Record 2 of Set 2 | pusad
# Processing Record 3 of Set 2 | clyde river
# Processing Record 4 of Set 2 | kavieng
# Processing Record 5 of Set 2 | chokurdakh
# Processing Record 6 of Set 2 | katsuura
# Processing Record 7 of Set 2 | saint-philippe
# Processing Record 8 of Set 2 | porto walter
# Processing Record 9 of Set 2 | jacqueville
# Processing Record 10 of Set 2 | nongan
# Processing Record 11 of Set 2 | mar del plata
# Processing Record 12 of Set 2 | nikolskoye
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | kaduy
# Processing Record 17 of Set 2 | tecoanapa
# Processing Record 18 of Set 2 | juneau
# Processing Record 19 of Set 2 | golden
# Processing Record 20 of Set 2 | lakes entrance
# Processing Record 21 of Set 2 | kaitangata
# Processing Record 22 of Set 2 | lampazos de naranjo
# Processing Record 23 of Set 2 | faanui
# Processing Record 24 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 2 | tabuk
# Processing Record 26 of Set 2 | butaritari
# Processing Record 27 of Set 2 | sitka
# Processing Record 28 of Set 2 | ekhabi
# Processing Record 29 of Set 2 | conselheiro lafaiete
# Processing Record 30 of Set 2 | te anau
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | ivanivka
# Processing Record 33 of Set 2 | caravelas
# Processing Record 34 of Set 2 | tabou
# Processing Record 35 of Set 2 | san jeronimo
# Processing Record 36 of Set 2 | qaanaaq
# Processing Record 37 of Set 2 | megion
# Processing Record 38 of Set 2 | pemba
# Processing Record 39 of Set 2 | waipawa
# Processing Record 40 of Set 2 | rosetta
# Processing Record 41 of Set 2 | palmer
# Processing Record 42 of Set 2 | suntar
# Processing Record 43 of Set 2 | pangnirtung
# Processing Record 44 of Set 2 | vila franca do campo
# Processing Record 45 of Set 2 | ribeira grande
# Processing Record 46 of Set 2 | boende
# Processing Record 47 of Set 2 | souillac
# Processing Record 48 of Set 2 | nouadhibou
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 0 of Set 3 | rawson
# Processing Record 1 of Set 3 | siverek
# Processing Record 2 of Set 3 | lahij
# Processing Record 3 of Set 3 | mut
# Processing Record 4 of Set 3 | rio gallegos
# Processing Record 5 of Set 3 | soe
# Processing Record 6 of Set 3 | xadani
# City not found. Skipping...
# Processing Record 7 of Set 3 | san patricio
# Processing Record 8 of Set 3 | port elizabeth
# Processing Record 9 of Set 3 | tiksi
# Processing Record 10 of Set 3 | hobart
# Processing Record 11 of Set 3 | port hedland
# Processing Record 12 of Set 3 | kapaa
# Processing Record 13 of Set 3 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 14 of Set 3 | bandarbeyla
# Processing Record 15 of Set 3 | karasburg
# Processing Record 16 of Set 3 | lata
# Processing Record 17 of Set 3 | gazanjyk
# Processing Record 18 of Set 3 | kavaratti
# Processing Record 19 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 3 | inhambane
# Processing Record 21 of Set 3 | lodja
# Processing Record 22 of Set 3 | posse
# Processing Record 23 of Set 3 | binon-an
# Processing Record 24 of Set 3 | ko samui
# Processing Record 25 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 3 | mahebourg
# Processing Record 27 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 3 | voh
# Processing Record 29 of Set 3 | vaitape
# Processing Record 30 of Set 3 | adrar
# Processing Record 31 of Set 3 | ust-maya
# Processing Record 32 of Set 3 | vao
# Processing Record 33 of Set 3 | pevek
# Processing Record 34 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 3 | ferkessedougou
# Processing Record 36 of Set 3 | la ronge
# Processing Record 37 of Set 3 | kralendijk
# Processing Record 38 of Set 3 | bonthe
# Processing Record 39 of Set 3 | karakendzha
# City not found. Skipping...
# Processing Record 40 of Set 3 | lasa
# Processing Record 41 of Set 3 | georgetown
# Processing Record 42 of Set 3 | victoria
# Processing Record 43 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 3 | seoul
# Processing Record 45 of Set 3 | isangel
# Processing Record 46 of Set 3 | alofi
# Processing Record 47 of Set 3 | namibe
# Processing Record 48 of Set 3 | east london
# Processing Record 49 of Set 3 | mecca
# Processing Record 0 of Set 4 | itaituba
# Processing Record 1 of Set 4 | north branford
# Processing Record 2 of Set 4 | khanpur
# Processing Record 3 of Set 4 | padang
# Processing Record 4 of Set 4 | valparaiso
# Processing Record 5 of Set 4 | tasiilaq
# Processing Record 6 of Set 4 | tazovskiy
# Processing Record 7 of Set 4 | bredasdorp
# Processing Record 8 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 4 | santona
# Processing Record 10 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 11 of Set 4 | chokwe
# Processing Record 12 of Set 4 | avera
# Processing Record 13 of Set 4 | kitgum
# Processing Record 14 of Set 4 | preobrazheniye
# Processing Record 15 of Set 4 | soavinandriana
# Processing Record 16 of Set 4 | ukiah
# Processing Record 17 of Set 4 | luderitz
# Processing Record 18 of Set 4 | atar
# Processing Record 19 of Set 4 | longyearbyen
# Processing Record 20 of Set 4 | taoudenni
# Processing Record 21 of Set 4 | severo-kurilsk
# Processing Record 22 of Set 4 | alta floresta
# Processing Record 23 of Set 4 | beyneu
# Processing Record 24 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 4 | narsaq
# Processing Record 26 of Set 4 | yellowknife
# Processing Record 27 of Set 4 | thompson
# Processing Record 28 of Set 4 | bambous virieux
# Processing Record 29 of Set 4 | upernavik
# Processing Record 30 of Set 4 | thunder bay
# Processing Record 31 of Set 4 | san cristobal
# Processing Record 32 of Set 4 | coquimbo
# Processing Record 33 of Set 4 | shevchenkove
# Processing Record 34 of Set 4 | fort nelson
# Processing Record 35 of Set 4 | hazorasp
# Processing Record 36 of Set 4 | muravlenko
# Processing Record 37 of Set 4 | sorland
# Processing Record 38 of Set 4 | tarabuco
# Processing Record 39 of Set 4 | marawi
# Processing Record 40 of Set 4 | yulara
# Processing Record 41 of Set 4 | nouna
# Processing Record 42 of Set 4 | fukue
# Processing Record 43 of Set 4 | laguna
# Processing Record 44 of Set 4 | grenaa
# Processing Record 45 of Set 4 | iralaya
# Processing Record 46 of Set 4 | calawag
# Processing Record 47 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 48 of Set 4 | fortuna
# Processing Record 49 of Set 4 | nuuk
# Processing Record 0 of Set 5 | bilma
# Processing Record 1 of Set 5 | los llanos de aridane
# Processing Record 2 of Set 5 | kaoma
# Processing Record 3 of Set 5 | abu samrah
# Processing Record 4 of Set 5 | moose factory
# Processing Record 5 of Set 5 | lompoc
# Processing Record 6 of Set 5 | rosarito
# Processing Record 7 of Set 5 | marabba
# Processing Record 8 of Set 5 | verkhneyarkeyevo
# Processing Record 9 of Set 5 | torbay
# Processing Record 10 of Set 5 | nanortalik
# Processing Record 11 of Set 5 | kyra
# Processing Record 12 of Set 5 | ponta do sol
# Processing Record 13 of Set 5 | dunedin
# Processing Record 14 of Set 5 | talah
# City not found. Skipping...
# Processing Record 15 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 5 | saskylakh
# Processing Record 17 of Set 5 | male
# Processing Record 18 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 5 | airai
# Processing Record 20 of Set 5 | belmonte
# Processing Record 21 of Set 5 | bolshaya dzhalga
# Processing Record 22 of Set 5 | college
# Processing Record 23 of Set 5 | vestmannaeyjar
# Processing Record 24 of Set 5 | pacific grove
# Processing Record 25 of Set 5 | horsens
# Processing Record 26 of Set 5 | key west
# Processing Record 27 of Set 5 | tilichiki
# Processing Record 28 of Set 5 | tiarei
# Processing Record 29 of Set 5 | cabedelo
# Processing Record 30 of Set 5 | grindavik
# Processing Record 31 of Set 5 | taman
# Processing Record 32 of Set 5 | lianzhou
# Processing Record 33 of Set 5 | andra
# Processing Record 34 of Set 5 | viedma
# Processing Record 35 of Set 5 | morondava
# Processing Record 36 of Set 5 | dukat
# Processing Record 37 of Set 5 | puerto penasco
# Processing Record 38 of Set 5 | toamasina
# Processing Record 39 of Set 5 | soyo
# Processing Record 40 of Set 5 | pontianak
# Processing Record 41 of Set 5 | kodiak
# Processing Record 42 of Set 5 | west odessa
# Processing Record 43 of Set 5 | komsomolskiy
# Processing Record 44 of Set 5 | kinkala
# Processing Record 45 of Set 5 | storforshei
# Processing Record 46 of Set 5 | toba
# Processing Record 47 of Set 5 | samarai
# Processing Record 48 of Set 5 | yumen
# Processing Record 49 of Set 5 | manzil salim
# Processing Record 0 of Set 6 | mocuba
# Processing Record 1 of Set 6 | beringovskiy
# Processing Record 2 of Set 6 | namatanai
# Processing Record 3 of Set 6 | hambantota
# Processing Record 4 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 6 | kidal
# Processing Record 6 of Set 6 | pacifica
# Processing Record 7 of Set 6 | flinders
# Processing Record 8 of Set 6 | ixtapa
# Processing Record 9 of Set 6 | atambua
# Processing Record 10 of Set 6 | nizwa
# Processing Record 11 of Set 6 | prado
# Processing Record 12 of Set 6 | chicama
# Processing Record 13 of Set 6 | port-gentil
# Processing Record 14 of Set 6 | miraflores
# Processing Record 15 of Set 6 | trairi
# Processing Record 16 of Set 6 | bubaque
# Processing Record 17 of Set 6 | cap malheureux
# Processing Record 18 of Set 6 | svetlaya
# Processing Record 19 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 20 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 21 of Set 6 | chapais
# Processing Record 22 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 6 | derzhavinsk
# Processing Record 24 of Set 6 | brylivka
# Processing Record 25 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 6 | cidreira
# Processing Record 27 of Set 6 | watertown
# Processing Record 28 of Set 6 | kamensk-uralskiy
# Processing Record 29 of Set 6 | savannah bight
# Processing Record 30 of Set 6 | choya
# Processing Record 31 of Set 6 | ahipara
# Processing Record 32 of Set 6 | one hundred mile house
# City not found. Skipping...
# Processing Record 33 of Set 6 | negele
# City not found. Skipping...
# Processing Record 34 of Set 6 | traverse city
# Processing Record 35 of Set 6 | paamiut
# Processing Record 36 of Set 6 | norman wells
# Processing Record 37 of Set 6 | paka
# Processing Record 38 of Set 6 | plettenberg bay
# Processing Record 39 of Set 6 | vostok
# Processing Record 40 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 41 of Set 6 | burley
# Processing Record 42 of Set 6 | sal rei
# Processing Record 43 of Set 6 | bid
# City not found. Skipping...
# Processing Record 44 of Set 6 | boa vista
# Processing Record 45 of Set 6 | ostrovnoy
# Processing Record 46 of Set 6 | kalemie
# Processing Record 47 of Set 6 | merauke
# Processing Record 48 of Set 6 | hvolsvollur
# Processing Record 49 of Set 6 | codrington
# Processing Record 0 of Set 7 | dalhousie
# Processing Record 1 of Set 7 | tateyama
# Processing Record 2 of Set 7 | pahrump
# Processing Record 3 of Set 7 | mackay
# Processing Record 4 of Set 7 | muros
# Processing Record 5 of Set 7 | ancud
# Processing Record 6 of Set 7 | bosaso
# Processing Record 7 of Set 7 | esperance
# Processing Record 8 of Set 7 | teya
# Processing Record 9 of Set 7 | guntakal
# Processing Record 10 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 7 | husavik
# Processing Record 12 of Set 7 | bada
# Processing Record 13 of Set 7 | aykhal
# Processing Record 14 of Set 7 | salalah
# Processing Record 15 of Set 7 | itaporanga
# Processing Record 16 of Set 7 | canals
# Processing Record 17 of Set 7 | muroto
# Processing Record 18 of Set 7 | sioux lookout
# Processing Record 19 of Set 7 | yoichi
# Processing Record 20 of Set 7 | bengkulu
# Processing Record 21 of Set 7 | acari
# Processing Record 22 of Set 7 | richards bay
# Processing Record 23 of Set 7 | erzin
# Processing Record 24 of Set 7 | vigrestad
# Processing Record 25 of Set 7 | kaspiyskiy
# Processing Record 26 of Set 7 | lagoa
# Processing Record 27 of Set 7 | sao joao da barra
# Processing Record 28 of Set 7 | saldanha
# Processing Record 29 of Set 7 | alausi
# Processing Record 30 of Set 7 | fondi
# Processing Record 31 of Set 7 | naze
# Processing Record 32 of Set 7 | poum
# Processing Record 33 of Set 7 | lorengau
# Processing Record 34 of Set 7 | dondo
# Processing Record 35 of Set 7 | kudahuvadhoo
# Processing Record 36 of Set 7 | wanning
# Processing Record 37 of Set 7 | beysehir
# Processing Record 38 of Set 7 | port lincoln
# Processing Record 39 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 7 | awjilah
# Processing Record 41 of Set 7 | tubara
# Processing Record 42 of Set 7 | myski
# Processing Record 43 of Set 7 | zhanakorgan
# Processing Record 44 of Set 7 | leningradskiy
# Processing Record 45 of Set 7 | makariv
# Processing Record 46 of Set 7 | kill
# Processing Record 47 of Set 7 | celestun
# Processing Record 48 of Set 7 | constitucion
# Processing Record 49 of Set 7 | cheran
# Processing Record 0 of Set 8 | xiangdong
# City not found. Skipping...
# Processing Record 1 of Set 8 | tuatapere
# Processing Record 2 of Set 8 | guerrero negro
# Processing Record 3 of Set 8 | yevlax
# Processing Record 4 of Set 8 | qui nhon
# Processing Record 5 of Set 8 | majene
# Processing Record 6 of Set 8 | duluth
# Processing Record 7 of Set 8 | portland
# Processing Record 8 of Set 8 | lusaka
# Processing Record 9 of Set 8 | eydhafushi
# Processing Record 10 of Set 8 | qusar
# Processing Record 11 of Set 8 | hayrabolu
# Processing Record 12 of Set 8 | geraldton
# Processing Record 13 of Set 8 | trinidad
# Processing Record 14 of Set 8 | cabo san lucas
# Processing Record 15 of Set 8 | santa rosa
# Processing Record 16 of Set 8 | freeport
# Processing Record 17 of Set 8 | beloha
# Processing Record 18 of Set 8 | hofn
# Processing Record 19 of Set 8 | bocana de paiwas
# Processing Record 20 of Set 8 | nioro
# Processing Record 21 of Set 8 | maldonado
# Processing Record 22 of Set 8 | altay
# Processing Record 23 of Set 8 | roald
# Processing Record 24 of Set 8 | ronneby
# Processing Record 25 of Set 8 | kupino
# Processing Record 26 of Set 8 | kirakira
# Processing Record 27 of Set 8 | dingle
# Processing Record 28 of Set 8 | paranaiba
# Processing Record 29 of Set 8 | las palmas
# Processing Record 30 of Set 8 | cervo
# Processing Record 31 of Set 8 | acapulco
# Processing Record 32 of Set 8 | rocha
# Processing Record 33 of Set 8 | puerto del rosario
# Processing Record 34 of Set 8 | bani walid
# Processing Record 35 of Set 8 | clarksburg
# Processing Record 36 of Set 8 | kizilskoye
# Processing Record 37 of Set 8 | bolobo
# Processing Record 38 of Set 8 | kikwit
# Processing Record 39 of Set 8 | ferme-neuve
# Processing Record 40 of Set 8 | saint-georges
# Processing Record 41 of Set 8 | trincomalee
# Processing Record 42 of Set 8 | pimentel
# Processing Record 43 of Set 8 | copiapo
# Processing Record 44 of Set 8 | hasaki
# Processing Record 45 of Set 8 | horqueta
# Processing Record 46 of Set 8 | takaungu
# Processing Record 47 of Set 8 | alice springs
# Processing Record 48 of Set 8 | blind river
# Processing Record 49 of Set 8 | roura
# Processing Record 0 of Set 9 | cayenne
# Processing Record 1 of Set 9 | bilibino
# Processing Record 2 of Set 9 | mount gambier
# Processing Record 3 of Set 9 | jumla
# Processing Record 4 of Set 9 | emerald
# Processing Record 5 of Set 9 | lexington
# Processing Record 6 of Set 9 | shkotovo-22
# City not found. Skipping...
# Processing Record 7 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 9 | guerande
# Processing Record 9 of Set 9 | olinda
# Processing Record 10 of Set 9 | nacunday
# City not found. Skipping...
# Processing Record 11 of Set 9 | sisophon
# Processing Record 12 of Set 9 | quthing
# Processing Record 13 of Set 9 | sumbe
# Processing Record 14 of Set 9 | zonguldak
# Processing Record 15 of Set 9 | middleton
# Processing Record 16 of Set 9 | gagret
# Processing Record 17 of Set 9 | nishihara
# Processing Record 18 of Set 9 | simbahan
# Processing Record 19 of Set 9 | jacksonville
# Processing Record 20 of Set 9 | euclides da cunha
# Processing Record 21 of Set 9 | ocampo
# Processing Record 22 of Set 9 | shubarkuduk
# Processing Record 23 of Set 9 | esso
# Processing Record 24 of Set 9 | kahului
# Processing Record 25 of Set 9 | pekin
# Processing Record 26 of Set 9 | norfolk
# Processing Record 27 of Set 9 | whitehorse
# Processing Record 28 of Set 9 | provideniya
# Processing Record 29 of Set 9 | vardo
# Processing Record 30 of Set 9 | rosario oeste
# Processing Record 31 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 9 | port hardy
# Processing Record 33 of Set 9 | bernalillo
# Processing Record 34 of Set 9 | araouane
# Processing Record 35 of Set 9 | sinnamary
# Processing Record 36 of Set 9 | rorvik
# Processing Record 37 of Set 9 | kruisfontein
# Processing Record 38 of Set 9 | vanderhoof
# Processing Record 39 of Set 9 | price
# Processing Record 40 of Set 9 | cockburn town
# Processing Record 41 of Set 9 | san andres
# Processing Record 42 of Set 9 | maarianhamina
# Processing Record 43 of Set 9 | unity
# Processing Record 44 of Set 9 | mayo
# Processing Record 45 of Set 9 | egvekinot
# Processing Record 46 of Set 9 | inta
# Processing Record 47 of Set 9 | imbituba
# Processing Record 48 of Set 9 | sorong
# Processing Record 49 of Set 9 | ustye
# Processing Record 0 of Set 10 | sisimiut
# Processing Record 1 of Set 10 | sabirabad
# Processing Record 2 of Set 10 | lubumbashi
# Processing Record 3 of Set 10 | yeppoon
# Processing Record 4 of Set 10 | menongue
# Processing Record 5 of Set 10 | joshimath
# Processing Record 6 of Set 10 | lososina
# Processing Record 7 of Set 10 | rosario
# Processing Record 8 of Set 10 | hovd
# Processing Record 9 of Set 10 | sokoto
# Processing Record 10 of Set 10 | ambon
# Processing Record 11 of Set 10 | kutum
# Processing Record 12 of Set 10 | martinsburg
# Processing Record 13 of Set 10 | gweta
# Processing Record 14 of Set 10 | dezhou
# Processing Record 15 of Set 10 | port macquarie
# Processing Record 16 of Set 10 | sao jose da coroa grande
# Processing Record 17 of Set 10 | kautokeino
# Processing Record 18 of Set 10 | tieling
# Processing Record 19 of Set 10 | tselinnoye
# Processing Record 20 of Set 10 | bucerias
# Processing Record 21 of Set 10 | temiscaming
# Processing Record 22 of Set 10 | surin
# Processing Record 23 of Set 10 | road town
# Processing Record 24 of Set 10 | beira
# Processing Record 25 of Set 10 | galle
# Processing Record 26 of Set 10 | saint anthony
# Processing Record 27 of Set 10 | agucadoura
# Processing Record 28 of Set 10 | tocopilla
# Processing Record 29 of Set 10 | iskateley
# Processing Record 30 of Set 10 | gondanglegi
# Processing Record 31 of Set 10 | pringsewu
# Processing Record 32 of Set 10 | kungalv
# Processing Record 33 of Set 10 | margate
# Processing Record 34 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 35 of Set 10 | benguela
# Processing Record 36 of Set 10 | bocaiuva
# Processing Record 37 of Set 10 | marsh harbour
# Processing Record 38 of Set 10 | virbhadra
# Processing Record 39 of Set 10 | charters towers
# Processing Record 40 of Set 10 | karlskrona
# Processing Record 41 of Set 10 | prince rupert
# Processing Record 42 of Set 10 | verkhoyansk
# Processing Record 43 of Set 10 | taiyuan
# Processing Record 44 of Set 10 | half moon bay
# Processing Record 45 of Set 10 | loukhi
# Processing Record 46 of Set 10 | klaksvik
# Processing Record 47 of Set 10 | tazmalt
# Processing Record 48 of Set 10 | hisor
# Processing Record 49 of Set 10 | desaguadero
# Processing Record 0 of Set 11 | terrace bay
# Processing Record 1 of Set 11 | hamilton
# Processing Record 2 of Set 11 | hirara
# Processing Record 3 of Set 11 | carutapera
# Processing Record 4 of Set 11 | raudeberg
# Processing Record 5 of Set 11 | karratha
# Processing Record 6 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 11 | skjervoy
# Processing Record 8 of Set 11 | meulaboh
# Processing Record 9 of Set 11 | sonoita
# Processing Record 10 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 11 | chernyshevskiy
# Processing Record 12 of Set 11 | grand gaube
# Processing Record 13 of Set 11 | amazar
# Processing Record 14 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 15 of Set 11 | saint-pierre
# Processing Record 16 of Set 11 | talnakh
# Processing Record 17 of Set 11 | makat
# Processing Record 18 of Set 11 | liverpool
# Processing Record 19 of Set 11 | pabrade
# Processing Record 20 of Set 11 | nuristan
# Processing Record 21 of Set 11 | maceio
# Processing Record 22 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 11 | bima
# Processing Record 24 of Set 11 | kismayo
# Processing Record 25 of Set 11 | mosquera
# Processing Record 26 of Set 11 | el balyana
# City not found. Skipping...
# Processing Record 27 of Set 11 | nemuro
# Processing Record 28 of Set 11 | rongcheng
# Processing Record 29 of Set 11 | coronel vivida
# Processing Record 30 of Set 11 | slave lake
# Processing Record 31 of Set 11 | buraydah
# Processing Record 32 of Set 11 | conde
# Processing Record 33 of Set 11 | kyshtovka
# Processing Record 34 of Set 11 | eregli
# Processing Record 35 of Set 11 | ogbomosho
# Processing Record 36 of Set 11 | portage
# Processing Record 37 of Set 11 | aberfeldy
# Processing Record 38 of Set 11 | orlik
# Processing Record 39 of Set 11 | yilan
# Processing Record 40 of Set 11 | itarema
# Processing Record 41 of Set 11 | taksimo
# Processing Record 42 of Set 11 | chikwawa
# Processing Record 43 of Set 11 | salekhard
# Processing Record 44 of Set 11 | nelson bay
# Processing Record 45 of Set 11 | cananea
# Processing Record 46 of Set 11 | sovetskiy
# Processing Record 47 of Set 11 | la union
# Processing Record 48 of Set 11 | estelle
# Processing Record 49 of Set 11 | vila velha
# Processing Record 0 of Set 12 | hirekerur
# Processing Record 1 of Set 12 | srandakan
# Processing Record 2 of Set 12 | lazaro cardenas
# Processing Record 3 of Set 12 | arrecife
# Processing Record 4 of Set 12 | marktoberdorf
# Processing Record 5 of Set 12 | thilogne
# City not found. Skipping...
# Processing Record 6 of Set 12 | antofagasta
# Processing Record 7 of Set 12 | raymond
# Processing Record 8 of Set 12 | taiping
# Processing Record 9 of Set 12 | yarim
# Processing Record 10 of Set 12 | bassila
# Processing Record 11 of Set 12 | santa fe
# Processing Record 12 of Set 12 | kathmandu
# Processing Record 13 of Set 12 | buzmeyin
# Processing Record 14 of Set 12 | vila
# Processing Record 15 of Set 12 | ilulissat
# Processing Record 16 of Set 12 | iquitos
# Processing Record 17 of Set 12 | tautira
# Processing Record 18 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 12 | inuvik
# Processing Record 20 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 21 of Set 12 | aklavik
# Processing Record 22 of Set 12 | atbasar
# Processing Record 23 of Set 12 | mpanda
# Processing Record 24 of Set 12 | rafai
# Processing Record 25 of Set 12 | port augusta
# Processing Record 26 of Set 12 | praia
# Processing Record 27 of Set 12 | tura
# Processing Record 28 of Set 12 | alyangula
# Processing Record 29 of Set 12 | axim
# Processing Record 30 of Set 12 | pangkalanbuun
# Processing Record 31 of Set 12 | staryy nadym
# Processing Record 32 of Set 12 | anderson
# Processing Record 33 of Set 12 | adre
# Processing Record 34 of Set 12 | ojinaga
# Processing Record 35 of Set 12 | reporoa
# Processing Record 36 of Set 12 | santa cruz
# Processing Record 37 of Set 12 | beroroha
# Processing Record 38 of Set 12 | bereda
# Processing Record 39 of Set 12 | kurchum
# Processing Record 40 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 41 of Set 12 | moron
# Processing Record 42 of Set 12 | kendari
# Processing Record 43 of Set 12 | boali
# Processing Record 44 of Set 12 | saint-joseph
# Processing Record 45 of Set 12 | bayshore gardens
# Processing Record 46 of Set 12 | tabora
# Processing Record 47 of Set 12 | nyagan
# Processing Record 48 of Set 12 | porbandar
# Processing Record 49 of Set 12 | walvis bay

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 554

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Abbeville  50.1000    1.8333     60.49        71          98       12.50
# 1      Ushuaia -54.8000  -68.3000     49.66        66          75       20.71
# 2       Xuddur   4.1213   43.8894     82.11        59          72        8.63
# 3     Mbandaka   0.0487   18.2603     83.14        63          95        4.32
# 4     Tessalit  20.1986    1.0114     98.51         6          28       10.07
# 5  Tuktoyaktuk  69.4541 -133.0374     14.00        85         100        3.44
# 6      Gravdal  68.1214   13.5031     46.29       100          75        2.30
# 7    Busselton -33.6500  115.3333     56.93        61           0        7.72
# 8      Rikitea -23.1203 -134.9692     77.29        72          86        9.15
# 9    Bathsheba  13.2167  -59.5167     84.81        65          40       14.97
#
#   Country                 Date Current Description
# 0      FR  2023-04-19 17:19:06     overcast clouds
# 1      AR  2023-04-19 17:19:06          light rain
# 2      SO  2023-04-19 17:19:06       broken clouds
# 3      CD  2023-04-19 17:19:07     overcast clouds
# 4      ML  2023-04-19 17:19:07    scattered clouds
# 5      CA  2023-04-19 17:19:07     overcast clouds
# 6      NO  2023-04-19 17:19:07       broken clouds
# 7      AU  2023-04-19 17:19:07           clear sky
# 8      PF  2023-04-19 17:15:11     overcast clouds
# 9      BB  2023-04-19 17:19:07    scattered clouds

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Abbeville  50.1000    1.8333     60.49        71          98       12.50
# 1      Ushuaia -54.8000  -68.3000     49.66        66          75       20.71
# 2       Xuddur   4.1213   43.8894     82.11        59          72        8.63
# 3     Mbandaka   0.0487   18.2603     83.14        63          95        4.32
# 4     Tessalit  20.1986    1.0114     98.51         6          28       10.07
# 5  Tuktoyaktuk  69.4541 -133.0374     14.00        85         100        3.44
# 6      Gravdal  68.1214   13.5031     46.29       100          75        2.30
# 7    Busselton -33.6500  115.3333     56.93        61           0        7.72
# 8      Rikitea -23.1203 -134.9692     77.29        72          86        9.15
# 9    Bathsheba  13.2167  -59.5167     84.81        65          40       14.97
#
#   Country                 Date Current Description
# 0      FR  2023-04-19 17:19:06     overcast clouds
# 1      AR  2023-04-19 17:19:06          light rain
# 2      SO  2023-04-19 17:19:06       broken clouds
# 3      CD  2023-04-19 17:19:07     overcast clouds
# 4      ML  2023-04-19 17:19:07    scattered clouds
# 5      CA  2023-04-19 17:19:07     overcast clouds
# 6      NO  2023-04-19 17:19:07       broken clouds
# 7      AU  2023-04-19 17:19:07           clear sky
# 8      PF  2023-04-19 17:15:11     overcast clouds
# 9      BB  2023-04-19 17:19:07    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"

# Recreate the DataFrame by using the new column order
city_data= city_data_df [["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description" ]]
# YOUR CODE HERE
# Display sample data# Display sample data
city_data_df.head
# Out:
# <bound method NDFrame.head of                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           Abbeville  50.1000   1.8333     60.49        71          98
# 1             Ushuaia -54.8000 -68.3000     49.66        66          75
# 2              Xuddur   4.1213  43.8894     82.11        59          72
# 3            Mbandaka   0.0487  18.2603     83.14        63          95
# 4            Tessalit  20.1986   1.0114     98.51         6          28
# ..                ...      ...      ...       ...       ...         ...
# 549  Bayshore Gardens  27.4253 -82.5904     84.24        46           0
# 550            Tabora  -5.0167  32.8000     66.56        86          30
# 551            Nyagan  62.1406  65.3936     26.74        94          55
# 552         Porbandar  21.6422  69.6093     82.38        61           2
# 553        Walvis Bay -22.9575  14.5053     69.87        60          24
#
#      Wind Speed Country                 Date Current Description
# 0         12.50      FR  2023-04-19 17:19:06     overcast clouds
# 1         20.71      AR  2023-04-19 17:19:06          light rain
# 2          8.63      SO  2023-04-19 17:19:06       broken clouds
# 3          4.32      CD  2023-04-19 17:19:07     overcast clouds
# 4         10.07      ML  2023-04-19 17:19:07    scattered clouds
# ..          ...     ...                  ...                 ...
# 549       12.66      US  2023-04-19 17:20:09           clear sky
# 550        4.27      TZ  2023-04-19 17:20:09    scattered clouds
# 551        5.23      RU  2023-04-19 17:20:09       broken clouds
# 552       11.12      IN  2023-04-19 17:20:09           clear sky
# 553       20.38      NA  2023-04-19 17:20:09          few clouds
#
# [554 rows x 10 columns]>

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv("city_data.csv",index=False)
